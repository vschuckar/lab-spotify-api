# %%
import pandas as pd
from time import sleep
import numpy as np
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import sys
from config import *

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))

# %%
hot_songs = pd.read_csv('~/Desktop/data_analytics/Week_6/Day_1/Afternoon/lab-not-hot-songs/hot_songs_updated.csv')

# %%
not_hot = pd.read_csv('~/Desktop/data_analytics/Week_6/Day_1/Afternoon/lab-not-hot-songs/not_hot_v2.csv')

# %%
not_hot.head()
# Out:
#    Unnamed: 0              artist                          title
# 0           0           Bob Dylan           Like a Rolling Stone
# 1           1  The Rolling Stones  (I Can't Get No) Satisfaction
# 2           2      The Beach Boys                Good Vibrations
# 3           3             Nirvana        Smells Like Teen Spirit
# 4           4     Aretha Franklin                        Respect

# %%
hot_songs.head()
# Out:
#    Unnamed: 0                              title        artist
# 0           0  Rockin' Around The Christmas Tree    Brenda Lee
# 1           1    All I Want For Christmas Is You  Mariah Carey
# 2           2                   Jingle Bell Rock   Bobby Helms
# 3           3                     Last Christmas         Wham!
# 4           4            A Holly Jolly Christmas     Burl Ives

# %%
hot_songs = hot_songs.drop('Unnamed: 0', axis = 1)
not_hot = not_hot.drop('Unnamed: 0', axis = 1)

# %%
def search_song(title, artist, limit = 1):
    '''
    Function to search a given single song in the Spotify API. 
    Input: title = song name, artist = song singer
    Output: Song id from Spotify
    '''
    
    search_query = f"track:{title} artist:{artist}"
    id = sp.search(q = search_query, limit = limit)['tracks']['items'][0]['id']
    return id

# %%
search_song("Like a Rolling Stone", "Bob Dylan")
# Out:
# '3AhXZa8sUQht0UEdBJgpGc'

# %% [markdown]
# ## Hot songs

# %%
def add_id(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Function to obtain the IDs of a given list of songs through the Spotify API.
    Input: pd.DataFrame
    Output: pd.DataFrae with the column "id" for each song
    Chunks used in order to prevent reaching the API request limit 
    '''
    
    chunks = 50
    list_of_ids = []

    for i in range(0, len(df), chunks):
        chunk = df.iloc[i:i+chunks]
        print("Collecting IDs for chunk...")
    
        for index, row in chunk.iterrows():
            title = row["title"]
            artist = row["artist"]
            try:
                id = search_song(title, artist, 1)
                list_of_ids.append(id)
            except:
                print("Song not found!")
                list_of_ids.append("")
        sleep(20)
        print("Sleep...")

    df["id"] = list_of_ids
    return df

# %%
add_id(hot_songs)
# Out:
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
#                                 title                                  artist  \
# 0   Rockin' Around The Christmas Tree                              Brenda Lee
# 1     All I Want For Christmas Is You                            Mariah Carey
# 2                    Jingle Bell Rock                             Bobby Helms
# 3                      Last Christmas                                   Wham!
# 4             A Holly Jolly Christmas                               Burl Ives
# ..                                ...                                     ...
# 95                 El Amor de Su Vida            Grupo Frontera & Grupo Firme
# 96               Standing Next To You                               Jung Kook
# 97                     Man Made A Bar     Morgan Wallen Featuring Eric Church
# 98                           Que Onda  Calle 24 x Chino Pacas x Fuerza Regida
# 99                       Great Gatsby                                Rod Wave
#
#                         id
# 0   2EjXfH91m7f8HiJN1yQg97
# 1   0bYg9bo50gSsH3LtXe2SQn
# 2   7vQbuQcyTflfCIOu3Uzzya
# 3   2FRnf9qhLbvw8fu4IBXx78
# 4   77khP2fIVhSW23NwxrRluh
# ..                     ...
# 95  0O3U5iwTbiXCREMkvotJuN
# 96  2KslE17cAJNHTsI2MI0jb2
# 97
# 98
# 99  4M68xjcc42oxyphhzpOWXS
#
# [100 rows x 3 columns]

# %%
list_of_ids = hot_songs["id"].tolist()

# %%
filtered_ids = [id for id in list_of_ids if id]

# %%
filtered_ids
# Out:
# ['2EjXfH91m7f8HiJN1yQg97',
#  '0bYg9bo50gSsH3LtXe2SQn',
#  '7vQbuQcyTflfCIOu3Uzzya',
#  '2FRnf9qhLbvw8fu4IBXx78',
#  '77khP2fIVhSW23NwxrRluh',
#  '3gBhiIj76UJQ7jlrUR4qjc',
#  '2uFaJJtFpPDc5Pa95XzTvg',
#  '0oPdaY4dXtc3ZsaG17V972',
#  '4xhsWYTOGcal8zt0J161CU',
#  '5ASM6Qjiav2xPe7gRkQMsQ',
#  '0lizgQ7Qw35od7CYaoMBZb',
#  '4PS1e8f2LvuTFgUs1Cn3ON',
#  '3YZE5qDV7u1ZD1gZc47ZeR',
#  '5mM1jHHXhKc0ZYi0R8EOLn',
#  '46pF1zFimM582ss1PrMy68',
#  '1TH5fhztFZmUGWaCXmZ6ie',
#  '3QiAAp20rPC3dcAtKtMaqQ',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '1foCxQtxBweJtZmdxhEHVO',
#  '25leEEaz1gIpp7o21Fqyjo',
#  '2pnPe4pJtq7689i5ydzvJJ',
#  '3ZfRpDV74gUbBCmW8yb6ml',
#  '3rUGC1vUpkDG9CZFHMur1t',
#  '5xlS0QkVrSH7ssEbBgBzbM',
#  '1SV1fxF65n9NhRHp3KlBuu',
#  '3QIoEi8Enr9uHffwInGIsC',
#  '2IGMVunIBsBLtEQyoI1Mu7',
#  '2QpN1ZVw8eJO5f7WcvUA1k',
#  '5aIVCx5tnk0ntmdiinnYvw',
#  '4mybTd8gHkEpCmMxOFKHwv',
#  '38xhBO2AKrJnjdjVnhJES6',
#  '7dJYggqjKo71KI9sLzqCs8',
#  '7K3BhSpAxZBznislvUMVtn',
#  '7xapw9Oy21WpfEcib2ErSA',
#  '3sDdyBHQ60Cs1opmIyRvhp',
#  '6NQchnlpozM5o4n6WfDznd',
#  '1OjmlSFuzYflWjSMTCyTJv',
#  '1DnSNqCQM3LUxqFuXt184Q',
#  '15sxLiiChE5dCW3Y756oas',
#  '0PAcdVzhPO4gq1Iym9ESnK',
#  '34MC0a5RRdXsfOEPAKiEd9',
#  '3bH2Eu9A9ymI4UnGHRmoXg',
#  '1Lo0QY9cvc8sUB2vnIOxDT',
#  '6usohdchdzW9oML7VC4Uhk',
#  '1Iq8oo9XkmmvCQiGOfORiz',
#  '0cVyQfDyRnMJ0V3rjjdlU3',
#  '1a73gcEg6h6Re6hHXoVltJ',
#  '0mflMxspEfB0VbI1kyLiAv',
#  '7MSWxMumjz6lHj7oRApNbg',
#  '41WQUSINanQHfhfKpFDsms',
#  '4OMJGnvZfDvsePyCwRGO7X',
#  '0J1YRLYhTG1MBosjidD7OI',
#  '5ya0TmUQw2wHMkq36rPsnd',
#  '0R6NfOiLzLj4O5VbYSJAjf',
#  '2gT2iF1YK5r54A2PDEXVv8',
#  '7DswEZZthZ6piQpL25qGAM',
#  '3vkCueOmm7xQDoJ17W1Pm3',
#  '0HD8mbiPjp3o94X3EaZp0o',
#  '4MjDJD8cW7iVeWInc2Bdyj',
#  '5mjYQaktjmjcMKcUIcqz4s',
#  '5Se32hEA9raeboZerywxka',
#  '2gyxAWHebV7xPYVxqoi86f',
#  '6CvTEtGagmzQvkUzzyKR9k',
#  '2kE2HFBFkJ0VMw3igxYohz',
#  '05WVKTdZhlIMX4qqMLuo0f',
#  '103u49mLoJUge83B1CnLxI',
#  '7hZTywPKMdVjJzwdWu11BK',
#  '5XVdHRf4CAJ2Jm0uMIy5qY',
#  '0eBFgRxyVSeuT4iyrbukdn',
#  '5RqSsdzTNPX1uzkmlHCFvK',
#  '3CWq0pAKKTWb0K4yiglDc4',
#  '6rjuKpPydT2SxN15TZpV7r',
#  '6UoKX6uLJwhsnyTp5k5StP',
#  '6uTPdRrEDeH8Fyg5L5qmeU',
#  '4bARASJEokNacSYtEhoNBp',
#  '6fNCrsrdIcgVd2aZZ0nnz4',
#  '18uSfZqFBxQFi8CsXOIbhy',
#  '7rr3gguU3TcVnLZD9VzASE',
#  '4qmG24ebshLXtKu9HIShBP',
#  '2Zo1PcszsT9WQ0ANntJbID',
#  '56xHMIfQPoe0prrSi3BGhf',
#  '0O3U5iwTbiXCREMkvotJuN',
#  '2KslE17cAJNHTsI2MI0jb2',
#  '4M68xjcc42oxyphhzpOWXS']

# %%
def get_audio_features(list_of_ids: list) -> pd.DataFrame:
    '''
    Function to obtain the audio features of a given list of songs 
    Input: List with the song ids 
    Output: pd.DataFrame with the audio features for each id
    Chunks used in order to prevent reaching the API request limit
    '''
    
    chunks = 50
    audio_features = []

    for i in range(0, len(list_of_ids), chunks):
        chunk_ids = list_of_ids[i:i+chunks]
        try:
            features_chunk = sp.audio_features(tracks = chunk_ids)
            if features_chunk:
                audio_features.extend(features_chunk)  
        except:
                print("Error retrieving audio features for chunk!")
                
        sleep(20)
        print("Sleep...")
        
    audio_features = [af for af in audio_features if af is not None]
    audio_features_df = pd.DataFrame(audio_features)

    return audio_features_df

# %%
audio_features_df = get_audio_features(filtered_ids)
# Out:
# Sleep...
# Sleep...

# %%
def add_audio_features(df: pd.DataFrame, audio_features_df: pd.DataFrame, key_column) -> pd.DataFrame:
    '''
    Function to merge the original df with the created df which has the song features.
    Input: df: pd.DataFrame -> original df, audio_features_df and the column on which both will merge 
    Output: The merged dataframe from the input ones
    '''

    merged_df = pd.merge(df, audio_features_df, how = 'inner', on = key_column)
    return merged_df

# %%
hot_features = add_audio_features(hot_songs, audio_features_df, 'id')

# %%
hot_features.head()
# Out:
#                                title        artist                      id  \
# 0  Rockin' Around The Christmas Tree    Brenda Lee  2EjXfH91m7f8HiJN1yQg97
# 1    All I Want For Christmas Is You  Mariah Carey  0bYg9bo50gSsH3LtXe2SQn
# 2                   Jingle Bell Rock   Bobby Helms  7vQbuQcyTflfCIOu3Uzzya
# 3                     Last Christmas         Wham!  2FRnf9qhLbvw8fu4IBXx78
# 4            A Holly Jolly Christmas     Burl Ives  77khP2fIVhSW23NwxrRluh
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.589   0.472    8    -8.749     1       0.0502         0.614
# 1         0.336   0.627    7    -7.463     1       0.0384         0.164
# 2         0.754   0.424    2    -8.463     1       0.0363         0.643
# 3         0.735   0.478    2   -12.472     1       0.0293         0.189
# 4         0.683   0.375    0   -13.056     1       0.0303         0.579
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.5050    0.898   67.196  audio_features
# 1          0.000000    0.0708    0.350  150.273  audio_features
# 2          0.000000    0.0652    0.806  119.705  audio_features
# 3          0.000002    0.3550    0.947  107.682  audio_features
# 4          0.000000    0.0760    0.888  140.467  audio_features
#
#                                     uri  \
# 0  spotify:track:2EjXfH91m7f8HiJN1yQg97
# 1  spotify:track:0bYg9bo50gSsH3LtXe2SQn
# 2  spotify:track:7vQbuQcyTflfCIOu3Uzzya
# 3  spotify:track:2FRnf9qhLbvw8fu4IBXx78
# 4  spotify:track:77khP2fIVhSW23NwxrRluh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2EjXfH91m7f8...
# 1  https://api.spotify.com/v1/tracks/0bYg9bo50gSs...
# 2  https://api.spotify.com/v1/tracks/7vQbuQcyTflf...
# 3  https://api.spotify.com/v1/tracks/2FRnf9qhLbvw...
# 4  https://api.spotify.com/v1/tracks/77khP2fIVhSW...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2EjX...       126267
# 1  https://api.spotify.com/v1/audio-analysis/0bYg...       241107
# 2  https://api.spotify.com/v1/audio-analysis/7vQb...       130973
# 3  https://api.spotify.com/v1/audio-analysis/2FRn...       262960
# 4  https://api.spotify.com/v1/audio-analysis/77kh...       135533
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
hot_features.shape
# Out:
# (84, 20)

# %%
hot_features.to_csv('hot_features.csv')

# %% [markdown]
# ## Not so hot

# %%
add_id(not_hot)
# Out:
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Song not found!
# Song not found!
# Sleep...
# Collecting IDs for chunk...
# Song not found!
# Song not found!
# Sleep...
#                   artist                          title  \
# 0              Bob Dylan           Like a Rolling Stone
# 1     The Rolling Stones  (I Can't Get No) Satisfaction
# 2         The Beach Boys                Good Vibrations
# 3                Nirvana        Smells Like Teen Spirit
# 4        Aretha Franklin                        Respect
# ...                  ...                            ...
# 2993  Black Box Recorder              The Facts of Life
# 2994           Bob Dylan    Just Like Tom Thumb's Blues
# 2995             Sebadoh                        On Fire
# 2996             Phoenix             Long Distance Call
# 2997        Otis Redding                        My Girl
#
#                           id
# 0     3AhXZa8sUQht0UEdBJgpGc
# 1     2PzU4IB8Dr6mxV3lHuaG34
# 2     5t9KYe0Fhd5cW6UYT4qP8f
# 3     5ghIJDpPoe3CfHMGu71E6T
# 4     7s25THrKz86DM225dOYwnr
# ...                      ...
# 2993  4eappNAqv5JsqWN1LJqpfY
# 2994  0V1771LhL3tG36pb55EZAH
# 2995  091SOmej015R3W0pUkc05v
# 2996  7dGubYmPavaI9YNansq9TW
# 2997  5zQyqgNXKzhifkivumzxDS
#
# [2998 rows x 3 columns]

# %%
list_of_ids_nothot = not_hot["id"].tolist()

filtered_ids_nothot = [id for id in list_of_ids_nothot if id]

filtered_ids_nothot
# Out:
# ['3AhXZa8sUQht0UEdBJgpGc',
#  '2PzU4IB8Dr6mxV3lHuaG34',
#  '5t9KYe0Fhd5cW6UYT4qP8f',
#  '5ghIJDpPoe3CfHMGu71E6T',
#  '7s25THrKz86DM225dOYwnr',
#  '2QfiRTz5Yc8DdShCxG1tB2',
#  '3zBhihYUHBmGd2bcQIobrF',
#  '1tqT6DhmsrtQgyCKUwotiw',
#  '5CQ30WqJwcep0pYcV4AMNc',
#  '3LoDeIbiR12sAznmpNEmKA',
#  '0iA3xXSkSCiJywKyo1UKjQ',
#  '1WN4uNclrDuczTO3bCr8s1',
#  '4u9f8hqstB7iITDJNzKhQx',
#  '5DuTNKFEjJIySAyJH1yNDU',
#  '1iUgrte2PxLxQ6Te95RnAV',
#  '3Am0IbOxmvlSXro7N5iSfZ',
#  '6tZdL3Zp8JgrfDbsSeSV1S',
#  '0hKRSZhUGEhKU6aNSPBACZ',
#  '34iOH7LY3vme5rQxsVILZ4',
#  '7qbpek8DcWai8wRhVOra2f',
#  '4pbG9SUmWIvsROVLF0zF9s',
#  '44BmNSqH9uZV5OfIjGcER3',
#  '6ui6l3ZNvlrGQZArwo8195',
#  '6AeyHqzNHJthYJbn0tvJ4b',
#  '6hTcuIQa0sxrrByu9wTD7s',
#  '7pKfPomDEeI4TPT6EOYjn9',
#  '5ASgsifUe53WvOggVdP844',
#  '2iXcvnD3d1gfLBum0cE5Eg',
#  '5ChkMS8OtdzJeqyybCc9R5',
#  '5LxvwujISqiB8vpRYv887S',
#  '2HCaIYjkvWSZzaSKUoOh3d',
#  '2N5zMZX7YeL1tico8oQxa9',
#  '5uvosCdMlFdTXhoazkTI5R',
#  '1Ud6moTC0KyXMq1Oxfien0',
#  '5jzma6gCzYtKB1DbEwFZKH',
#  '21TLMicT1xwHp5StlDbQoE',
#  '0aym2LBJBk9DAYuHHutrIl',
#  '1h2xVEoJORqrg71HocgqXd',
#  '6QyQmdvQ1ywNccYa0pwLNQ',
#  '1GOdYykgw2W0OcjPANvwgE',
#  '1wVzaWcWFokOmspmaXoUhX',
#  '2PpruBYCo4H7WOBJ7Q2EwM',
#  '31AOj9sFz2gM0O3hMARRBx',
#  '51H2y6YrNNXcy3dfc3qSbA',
#  '5Viurwg2LYZjky18hqJN7J',
#  '2kkvB3RNRzwjFdGhaUA0tz',
#  '57iDDD9N9tTWe75x6qhStw',
#  '1JSTJqkT5qHq8MDJnJbRE1',
#  '2fXKyAyPrEa24c6PJyqznF',
#  '6iGU74CwXuT4XVepjc9Emf',
#  '6rLqjzGV5VMLDWEnuUqi8q',
#  '6hHc7Pks7wtBIW8Z6A0iFq',
#  '3G0EALIIp5DAeIERxXBHmo',
#  '6pxWv6GV35VGmcPf5dh6CH',
#  '64Ny7djQ6rNJspquof2KoX',
#  '5p3JunprHCxClJjOmcLV8G',
#  '5PntSbMHC1ud6Vvl8x56qd',
#  '7Jh1bpe76CNTCgdgAdBw4Z',
#  '7BY005dacJkbO6EPiOh2wb',
#  '63xdwScd1Ai1GigAwQxE8y',
#  '2Yply65U0i60PA5XZMYNC2',
#  '0j5FJJOmmnXPd0XajFWkMF',
#  '1H5IfYyIIAlgDX8zguUzns',
#  '3SdTKo2uVsxFblQjpScoHy',
#  '7tFiyTwD0nx5a1eklYtX2J',
#  '6l8EbYRtQMgKOyc1gcDHF9',
#  '20I8RduZC2PWMWTDCZuuAN',
#  '6TlQ5fbojNRuG0hPQMbxeW',
#  '51FpzuGkRYXFgsE2zXt9av',
#  '423hwXFgoN8RYmqLoLuVvY',
#  '5d6ZRqgbz26Sg4bk1oifQw',
#  '0hCB0YR03f6AmQaHbwWDe8',
#  '45Szkclj1lt4ubm7RFK68t',
#  '3SQhmctWreNM0X6Zkm2K5R',
#  '3oAWTk92mZBxKBOKf8mR5v',
#  '2wYKNcoqKW4IEcllj42xz1',
#  '6LEXD2N3PxSmu4BMUHjaTb',
#  '4bpR5ueJGgjcO6QmKP5FHH',
#  '6qUEOWqOzu1rLPUPQ1ECpx',
#  '1yo16b3u0lptm6Cs7lx4AD',
#  '0GvhHQbWSnGltjl0je61dI',
#  '5IVuqXILoxVWvWEPm82Jxr',
#  '4fQMGlCawbTkH9yPPZ49kP',
#  '4N1dFbXmRng8qJ3KdJrbLr',
#  '4NRQwaks9r58tTDvr4iEyv',
#  '7snQQk1zcKl8gZ92AnueZW',
#  '0KOE1hat4SIer491XKk4Pa',
#  '2hWKJO4c9L7kJmX4pBV6j8',
#  '1TKPfF2fvn6gVLVfp3iG4j',
#  '3G69vJMWsX6ZohTykad2AU',
#  '6ewN9MaFbi78oDLT9wYDgn',
#  '7tHI0AluH3HIMRoIdS37jy',
#  '4s6LhHAV5SEsOV0lC2tjvJ',
#  '25IiJu0DjOqsnQXgNHWp5i',
#  '0qsS2A3hwicJCLtcaR6JRQ',
#  '5GHY1DFWKz3Prg2V0Iodqo',
#  '3yrSvpt2l1xhsV9Em88Pul',
#  '1qRA5BS78u3gME0loMl9AA',
#  '6rovOdp3HgK1DeAMYDzoA7',
#  '2OARIMw1hpehr86Iwmv04c',
#  '1FvDJ9KGxcqwv1utyPL3JZ',
#  '745H5CctFr12Mo7cqa1BMH',
#  '7ygpwy2qP3NbrxVkHvUhXY',
#  '72Z17vmmeQKAg8bptWvpVG',
#  '3xsOtNxtBW0oTI1OWKAzTm',
#  '6FsQrRpBLgsrFeAeiQqytm',
#  '1CTex49P0iWwzUGsMNjgaV',
#  '3bUNyRrTFJDd4mqvUcb1Aa',
#  '48i055G1OT5KxGGftwFxWy',
#  '3BQHpFgAp4l80e1XslIjNI',
#  '4BP3uh0hFLFRb5cjsgLqDh',
#  '1DKyFVzIh1oa1fFnEmTkIl',
#  '0GjEhVFGZW8afUYGChu3Rr',
#  '1FTSo4v6BOZH9QxKc3MbVM',
#  '7DsQgIwg23u9gooCxkRTu3',
#  '215Qx4WvrjXhFHXnswRK3s',
#  '7HIG9Utsra6sL79nA1Tn0y',
#  '2BGNomqCxEDcXyxf8bg27k',
#  '64VP3skE86iTvdOlbzuIcO',
#  '0HUp7ipIDJvITTqizN6cxJ',
#  '4f3u4Oy0JqJRIhMmTqRcxj',
#  '6H3kDe7CGoWYBabAeVWGiD',
#  '5Lno0hPhvo7BzXVLQzDIS3',
#  '38Ngied9rBORlAbLYNCl4k',
#  '7CqFMR3yj95Yuwagq5XsLR',
#  '3KfbEIOC7YIv90FIfNSZpo',
#  '3VZmChrnVW8JK6ano4gSED',
#  '70LcF31zb1H0PyJoS1Sx1r',
#  '2fDHuS1PTkHBbCWWZF1ph9',
#  '7mCQK9YB25WZw1saUjfL4e',
#  '6k9DUKMJpWvu6eFG3O64Lg',
#  '6AeG6jSoAVbmUFO6LyYmBf',
#  '0PkBTqRtN25z3oKasWoKlj',
#  '62LJFaYihsdVrrkgUOJC05',
#  '2ivdsb1RcEJjIs5tuHkUC9',
#  '6nWneWHV6S5FhXkVBeMoLE',
#  '52FlwUMMDnTK8TGkCag9Jd',
#  '6oRHRkQigTzJ3KwpO3XOV6',
#  '4rS63BySQrdWuTswkkZ5iS',
#  '3zpj9dvJABiyMrmLCPw6i8',
#  '45xBWOa6oEAk1WlVyr5QAB',
#  '0cGG2EouYCEEC3xfa0tDFV',
#  '4KcH1ZRV2W1q7Flq0QqC76',
#  '7aLoa1F3EoM8AeC6Ao1RKz',
#  '2aEeghgUcnu75tzcolFMfs',
#  '0LrwgdLsFaWh9VXIjBRe8t',
#  '5ZgNecJcN9SSopnmCTlpXs',
#  '3fElupNRLRJ0tbUDahPrAb',
#  '7DD7eSuYSC5xk2ArU62esN',
#  '7N3PAbqfTjSEU1edb2tY8j',
#  '61UuPxxYUvacEH6SHIK3sU',
#  '3dPQuX8Gs42Y7b454ybpMR',
#  '1h04XMpzGzmAudoI6VHBgA',
#  '2rfrVFsToevCxsDBUzLW5N',
#  '1FnxNtKli7rcB9IU4J8MEg',
#  '3ZjrfGcb3A2PMGA1vRNgSk',
#  '2mv6GY70UsHiTCGQZ4JfgC',
#  '5IyL3XOaRPpTgxVjRIAxXU',
#  '1dZxI6OuzwJ283y3gOU1Kq',
#  '1auX4gkGe7hbrOH0BXdpV4',
#  '1OOtq8tRnDM8kG2gqUPjAj',
#  '0fonScmHUzC0MglSLn9saA',
#  '75IN3CtuZwTHTnZvYM4qnJ',
#  '7dblNGnRXEBrVJunazs2U5',
#  '1KdwPeY1WRWQGHCmRJTveb',
#  '4w2XBHvs8g1HNf406G1vbB',
#  '56lhDZNQ5J47aog6mGKeGk',
#  '7jGzYUZ2Bgg8BDfYlQRfn8',
#  '5BiuxSuxOZ9CcQ6SqICsDv',
#  '2R7uUQ0Dehu80gsOcydQC9',
#  '1PS1QMdUqOal0ai3Gt7sDQ',
#  '6V9VCm1zOY2lGR80RehJ9i',
#  '1ZPlNanZsJSPK5h9YZZFbZ',
#  '1YrnDTqvcnUKxAIeXyaEmU',
#  '1mnqraQ8oV8MX92rdOFLWW',
#  '1Y373MqadDRtclJNdnUXVc',
#  '43nPS5X2znrSATwlX0Usm8',
#  '2He3NOyqtLNE3RQPpeDdSb',
#  '5by3w3NXvwDpV9FBSOR35u',
#  '00oZhqZIQfL9P5CjOP6JsO',
#  '1sd6f5ipZ80LBUF569dhxY',
#  '24lvdbt9pS7DFEjhEWSl49',
#  '0dOg1ySSI7NkpAe89Zo0b9',
#  '7AzFID6u1b3zIWbd9pb8Dk',
#  '0P7DoyGrr4Wp9w5TotEtUC',
#  '0I3q5fE6wg7LIfHGngUTnV',
#  '0WQiDwKJclirSYG9v5tayI',
#  '31uidLEHAcF8Cw1cX1VCS8',
#  '3qCHUm73I3o5F1mDEfibzo',
#  '63T7DJ1AFDD6Bn8VzG6JE8',
#  '4v2rkl1mC3zVAz0nXMx9r4',
#  '7odHgoLFi3GQ90E9PeraI3',
#  '0WNGPpmWqzPnk0psUhJ3SX',
#  '2K22nUTdyr48JDwI5t906t',
#  '4B3gkbr7aGC2sujjgivK0s',
#  '452KBpASS5lZLeJWX9Ixub',
#  '3lN8PP6R2IxbLP05QpYXng',
#  '3NfxSdJnVdon1axzloJgba',
#  '5CeL9C3bsoe4yzYS1Qz8cw',
#  '5FsDG7qnuy6T3x1u1OcQtG',
#  '4YCnTYbq3oL1Lqpyxg33CU',
#  '0MrkkxbgfHfbxrTg12oHd4',
#  '69RH84na5iUNwrwxpgjC5j',
#  '1KGi9sZVMeszgZOWivFpxs',
#  '06PdA0DLgF4BfAeUNZAbFG',
#  '7MF7QAodbGzNYav5ZfIhAY',
#  '4vpeKl0vMGdAXpZiQB2Dtd',
#  '7jIAttgQTpLDoNtykIQXjH',
#  '5y788ya4NvwhBznoDIcXwK',
#  '1XuccRABkfUVB4FjSVhjL1',
#  '5fpizYGbi5IQoEraj6FP0R',
#  '3CIOopLwvyMvXk97ZEksKO',
#  '3UmaczJpikHgJFyBTAJVoz',
#  '6C4LXC9UFH1IKiHYOp0BiJ',
#  '6I9VzXrHxO9rA9A5euc8Ak',
#  '0Puj4YlTm6xNzDDADXHMI9',
#  '1TrGdXSgiBm8W68D2K1COG',
#  '1QaJWSCk3UMKLotnPCIHh1',
#  '507IFqPuG8mBQoKebfGG9t',
#  '6YffUZJ2R06kyxyK6onezL',
#  '6eE6akYdf9w2rZUOIMwSgw',
#  '5vMTfupz6z7wlNiz0xVb4j',
#  '3YdKJzcoMZMacISlpY4QoP',
#  '2m0M7YqCy4lXfedh18qd8N',
#  '07GvNcU1WdyZJq3XxP0kZa',
#  '6BT7qiDY4A5tOyklohjQuW',
#  '1i6N76fftMZhijOzFQ5ZtL',
#  '5haXbSJqjjM0TCJ5XkfEaC',
#  '0NWPxcsf5vdjdiFUI8NgkP',
#  '58PSYdY0GFg0LFb2PxYk4T',
#  '36AlMHDBFwSsD3FQOy1R81',
#  '7KMILVTQdVS4zQ8ilTcpRO',
#  '0Ui8KPWZbJJQ2Y0CIQuVqX',
#  '303ccTay2FiDTZ9fZ2AdBt',
#  '0ZvgXNstN4o2ZXPomtBYVp',
#  '46dGFTD918NMz1IP1rPJXO',
#  '7wj3PmmPSDuPcpoxFXCea2',
#  '3VqHuw0wFlIHcIPWkhIbdQ',
#  '0GVvRmCoiLkhxJvlZy9bLk',
#  '1MQWtVcs0PKsY4PA6ZvLiy',
#  '6Ly9aeqAbqAkiGt9Dost5p',
#  '2QvIOJ4EIz4MIwWRpKG4mi',
#  '4c6vZqYHFur11FbWATIJ9P',
#  '5QTxFnGygVM4jFQiBovmRo',
#  '3v9xlH6BpmRbqL7hgNJhfT',
#  '1YZuigG1YcdgbfD7XJoCU5',
#  '6UP5zTAuR4NFc1uZ3MHjvA',
#  '5EWPGh7jbTNO2wakv8LjUI',
#  '6wKXuvOQxG5Ui1Kv2F68E9',
#  '1oht5GevPN9t1T3kG1m1GO',
#  '3Lbxie6whOW4eMt4jtI32k',
#  '0CcL4kSHKIEwF3IW0BGgb6',
#  '5qyq1H5OPMlfuvZQ1wQNo7',
#  '1U9aFSVZ08JVA5E3YD0TDe',
#  '0WwmFdGXe7Yky4T2J1oqLk',
#  '1XlDNpWy8dyEljyRd0RC2J',
#  '4NeOWqHmlrGRuBvsLJC9rL',
#  '2s4B4fUlVIkE4ELgoupjXL',
#  '1z3ugFmUKoCzGsI6jdY4Ci',
#  '2BkXpZSvPoUDMLI2Xw9kAL',
#  '6Vcwr9tb3ZLO63F8DL8cqu',
#  '2mKj8Em0GLFu8I78yM1CfU',
#  '6qspW4YKycviDFjHBOaqUY',
#  '3d9DChrdc6BOeFsbrZ3Is0',
#  '3BdoWtWx0tuYgJziTESrjP',
#  '1fDsrQ23eTAVFElUMaf38X',
#  '3YW3Tw3lLQfuPfklE76F3y',
#  '6xatfNMI8NkY5XxRHAeiS4',
#  '4Fpsa3pYc3gozrxHRRPvR6',
#  '3KSchPNSklO5McIqRH3qYX',
#  '7CZiDzGVjUssMSOXrDNYHL',
#  '11LmqTE2naFULdEP94AUBa',
#  '4hLATN2VtjiJ6jLm6V47x1',
#  '18GiV1BaXzPVYpp9rmOg0E',
#  '21Qsj3cMVCx2xF2EVVNbEu',
#  '2oZmMp5M6L0Rh7G84Um2tF',
#  '2WODVps1PWm5KHCXlpe7Mw',
#  '2Q5wSOwq6BDSu7sSVMNrtT',
#  '1TfqLAPs4K3s2rJMoCokcS',
#  '672N8DGGTOLCOgWe0koX5g',
#  '38zsOOcu31XbbYj9BIPUF1',
#  '6eLL7QTdMWdhhG4i3jHDR9',
#  '4gvea7UlDkAvsJBPZAd4oB',
#  '4ZEEcEMGjkWOfZNBcIB9yE',
#  '6O5PIO5pAWxdoxvaUFQ02G',
#  '6RJK553YhstRzyKA4mug09',
#  '2Cdvbe2G4hZsnhNMKyGrie',
#  '3dh2LlmeMqKJbzn2WUgt3d',
#  '6gbdLLUhocAjThL3GvV6Lx',
#  '6nGUM3Z0FNJZW9wbNj97Ig',
#  '2QSUyofqpGDCo026OPiTBQ',
#  '5cy5IStIn7OSHDEIgXeDyq',
#  '6ALPLbDJ9eWVij9ep3Cgf4',
#  '6MtUqawGQyVO1f8tWdVGjy',
#  '6LERtd1yiclxFH8MHAqr0Q',
#  '3sLhMSePzxSrmxluIqeoAZ',
#  '3UDmHZcBTQp8Iu8droNtUl',
#  '6ADSaE87h8Y3lccZlBJdXH',
#  '1O1mCVN5hue4lOOqd5EysZ',
#  '4Dq749x2QP6OXTURJ9GGY8',
#  '1QEEqeFIZktqIpPI4jSVSF',
#  '20OFwXhEXf12DzwXmaV7fj',
#  '3v30QiQtdQQAUIWwfKByN7',
#  '62nQ8UZVqR2RMvkJHkcO2o',
#  '3WibbMr6canxRJXhNtAvLU',
#  '7Me0vOSlJfaPY7Pc4GeItd',
#  '1DndHckdH9m5rp6gYP086b',
#  '6yMGxqKj0218mFR5KqsMRq',
#  '0uEp9E98JB5awlA084uaIg',
#  '5s6DOElzncE6h3kr2UjaUM',
#  '4JfuiOWlWCkjP6OKurHjSn',
#  '1T6lR1zTxvh4xzEn1M48Gc',
#  '5n8Aro6j1bEGIy7Tpo7FV7',
#  '7mNFrf8IfgaWMFCz64CtK4',
#  '2FkCjtQ1lYsf71s2FAS8hE',
#  '3EYOJ48Et32uATr9ZmLnAo',
#  '7FIhuHZUdUxWX2hDMGdIbF',
#  '0CAJdthKDdRjB2h8YOguN6',
#  '3xrn9i8zhNZsTtcoWgQEAd',
#  '2GUEXn64HZhMo6sdzjLPdg',
#  '7Kszjzps0xbQXyo1pO4KfE',
#  '4eGHlplaq1ME8oetnTuFFf',
#  '73CKjW3vsUXRpy3NnX4H7F',
#  '39Bd345OWEhRNyfayhp9gv',
#  '6LgJvl0Xdtc73RJ1mmpotq',
#  '3AJwUDP919kvQ9QcozQPxg',
#  '7oYpzJ79R3RAJOfBvUKVjb',
#  '1wl5b2lw3YagQtZiYZbQWP',
#  '1yvkKwvTiQmq0Saw1quM9l',
#  '1v98rfd0an913AzHvMNG8a',
#  '4ZVZBc5xvMyV3WzWktn8i7',
#  '5Z01UMMf7V1o0MzF86s6WJ',
#  '21YxK0klhpfLW8budkJaMF',
#  '6XHbYnwTB7YoSV4TLeycuB',
#  '5GjPQ0eI7AgmOnADn1EO6Q',
#  '10vkYRKw6Jjr7try1ir50G',
#  '71LsKf3xISiOlY1mj7FFPP',
#  '4gAU0cHQJFxj1n2ZDiEIzG',
#  '272Z4tzaSMMcgrZ0R494S2',
#  '11XR0tRT4g5ov4u8M92wbF',
#  '389QX9Q1eUOEZ19vtzzI9O',
#  '2ZMTbJnURHVmEw1wvsXf40',
#  '6xxXrNJnnsQNLdgNk8S4y8',
#  '2s0ouHqJebHfiQ6C1GUFJd',
#  '1hClDWPgajpLIFjLOkFuau',
#  '1cLfXnBwTFuRngRZfQeLof',
#  '5zuQyE2dJWjGTbdpaMxmMA',
#  '7yMiX7n9SBvadzox8T5jzT',
#  '2EoOZnxNgtmZaD8uUmz2nD',
#  '1IqFh00G2kvvMm8pRMpehA',
#  '7LoGfKBAaOl0nxhodJ1240',
#  '2HUZVffVPXvqnrml0gXggp',
#  '6Pq9MmkDQYZiiCDpxnvrf6',
#  '7rIovIsXE6kMn629b7kDig',
#  '0u5sJJNGHZUvckdMe96TkA',
#  '0gqYQBiXksbJ8dMpkwy9ne',
#  '2M9ro2krNb7nr7HSprkEgo',
#  '7xOzla5lnYaOW7n8RtDZMM',
#  '7B9F9nLxe7MZgZ68Jj86Fn',
#  '74njazGdnO2igjEkb0mGiy',
#  '76GlO5H5RT6g7y0gev86Nk',
#  '37ZJ0p5Jm13JPevGcx4SkF',
#  '4NQfrmGs9iQXVQI9IpRhjM',
#  '568SEFtDjKr7N2PytpA6D5',
#  '4h2jrA7MTbFNk1HK1FYdak',
#  '3T5AtZHfROthygPMNipfZC',
#  '7sLpSWxQazJzDVG6YGzlVs',
#  '5Z8EDau8uNcP1E8JvmfkZe',
#  '6Vjk8MNXpQpi0F4BefdTyq',
#  '2SiXAy7TuUkycRVbbWDEpo',
#  '0lIoY4ZQsdn5QzhraM9o9u',
#  '4RY96Asd9IefaL3X4LOLZ8',
#  '3ZE3wv8V3w2T2f7nOCjV0N',
#  '1JJ8D0KE144weLOGrjqJrb',
#  '4GvyP7CnBJEV2t7L7vOkjw',
#  '4PRGxHpCpF2yoOHYKQIEwD',
#  '3t5C5qQI3wqJasYIKOJEB7',
#  '4KM77RUl2IKdXGhtOBbKIS',
#  '0mlwPYU0ApElSjZN4yA4L9',
#  '6wpGqhRvJGNNXwWlPmkMyO',
#  '3850dYVgOFIXJh5U4BFEWH',
#  '1mH7MvtshIFTz2eEv8AZ16',
#  '7dSBZzVmyBaLDxT2v3EJHB',
#  '2GImcOxFZ0GP49rmPnPOjT',
#  '2nqpN3cSmL0tTlJ724fE2a',
#  '3jS7bB0oXVOwGFZn3aE5NV',
#  '7iN1s7xHE4ifF5povM6A48',
#  '2Z0X7jTNkYjpehGET2vnHE',
#  '4so0Wek9Ig1p6CRCHuINwW',
#  '0myfUjrUP8kMrk48nOXAY0',
#  '1k28sDTLOz942qa3wEtMQE',
#  '5QLHGv0DfpeXLNFo7SFEy1',
#  '3E5ndyOfO6vFDEIE42HA8o',
#  '3MjUtNVVq3C8Fn0MP3zhXa',
#  '4xlEKYv7HmC8zXoJIbpZKM',
#  '3X9fXH0FzBloyaUkz5qr0C',
#  '4y1LsJpmMti1PfRQV9AWWe',
#  '6zFsz86nAj5gcvzyVqNL3k',
#  '1vnKvlb6cj5NLpd1BMJ2jD',
#  '4591VqUIXysNlmI5NcAIUd',
#  '0YgoNapnyIXuruBrzvoCSu',
#  '7e89621JPkKaeDSTQ3avtg',
#  '11fNLqDB47gMKj7BHhR2Qr',
#  '1OppEieGNdItZbE14gLBEv',
#  '4QQEzkxcONBthDLfzqIh9S',
#  '5J2CHimS7dWYMImCHkEFaJ',
#  '20s3FayrStM8GY0m4dRFsw',
#  '0Hw6SCrtU9pFCjgAONpnGZ',
#  '2XIr0KTybGQsC1SFfeaZhI',
#  '3cw3Z7mS55gd3NUjh4k0bL',
#  '52dm9op3rbfAkc1LGXgipW',
#  '2pzpApfqE2LaXW5StD1FUA',
#  '6KBsivP3Of4z2x6uNMAyE3',
#  '2xtC6kb6H26qVX4ZdncS7f',
#  '4FdDorlbJTVHcH3djLbIfn',
#  '1PtQJZVZIdWIYdARpZRDFO',
#  '6q9rNSvE59IVT3ZlEorvYb',
#  '6cr6UDpkjEaMQ80OjWqEBQ',
#  '4tBl1xhBg5PETpBvFnQmGl',
#  '3Xe4JagghOfs9NF1xaqbb8',
#  '55MEbqyxZphjB0beZ7YT0f',
#  '3NElqDNNnzvWYOwsbxLQKN',
#  '54X78diSLoUDI3joC2bjMz',
#  '6HvUtPLqkP0t6zd6YNdWby',
#  '2Di0qFNb7ATroCGB3q0Ka7',
#  '421Gp1eSmOIcD6alTWowFR',
#  '65lehSrL7IvTOvKuM83dd9',
#  '1xsYj84j7hUDDnTTerGWlH',
#  '5uBKhKWTJ4E47rcLQqu3YH',
#  '4dyx5SzxPPaD8xQIid5Wjj',
#  '4K6ty4NwXYb21ahsV8Fikb',
#  '6em28nuZc5x4rNynqkrMpE',
#  '0d28khcov6AiegSCpG5TuT',
#  '4Tjs8b6jL1s18sjURJtswp',
#  '6vTtCOimcPs5H1Jr9d0Aep',
#  '56KqaFSGTb7ifpt16t5Y1N',
#  '2K2M0TcglCRLLpFOzKeFZA',
#  '0sZy1HE2aGBQABHfVRQ4jB',
#  '0WDWw71XzofIWsnQxILmSI',
#  '43DeSV93pJPT4lCZaWZ6b1',
#  '4uGIJG1jYFonGc4LGp5uQL',
#  '5NoQvINZLBV1wMYPdNmReL',
#  '1GVnAD8Iz45rux6EC657Yv',
#  '3XWgwgbWDI56mf1Wl3cLzb',
#  '2CwMxEXxMiLRrKPLjQLmne',
#  '3j09lTAcPqqFNT33cpF4vf',
#  '7uPmQttafLiJyju14JREY4',
#  '6ITuEsxEy2qPhqMowdDAeI',
#  '1hES47PrbU8GPTI5A9lsr0',
#  '6hu1f1cXSw7OAqhpSQ2zDy',
#  '6Hy22YDN9HJMRlJP1LwnJy',
#  '1Cwsd5xI8CajJz795oy4XF',
#  '6jX5mso4x00c1EiNMrTU9U',
#  '1N4MKISvC1ddfRCRQDXDd2',
#  '6TYR3IVgIwDK6ydc2EPEQq',
#  '28cnXtME493VX9NOw9cIUh',
#  '0pNeVovbiZHkulpGeOx1Gj',
#  '4Hhv2vrOTy89HFRcjU3QOx',
#  '14XWXWv5FoCbFzLksawpEe',
#  '2dpO3NteNWUDL2S9e0t0Mi',
#  '5nkcHStGMrEDph0DkuYSEk',
#  '7L93GESzq43UkKUt5FsOCq',
#  '6C7aTTCUWRK7dD379yUT3W',
#  '2BcOZ4vOeu2qZowIHrvTYy',
#  '6UBjSnyP1O5W5ndJoO9vUk',
#  '3DQVgcqaP3iSMbaKsd57l5',
#  '27QvYgBk0CHOVHthWnkuWt',
#  '3wtMkvedoWMQ3XTKv7tqcZ',
#  '0uppYCG86ajpV2hSR3dJJ0',
#  '62D6e3vF4sRP59olXwSDtd',
#  '6dRX3GyCjrxHm8o5VcIM0h',
#  '1Ic9pKxGSJGM0LKeqf6lGe',
#  '5XTLMydD8xxGabWEKrX87i',
#  '6sT9MWlJManry3EQwf4V80',
#  '4hq0S6wznq7SHDyMOFXL9i',
#  '6Zgd7SomLTZkL1WPh4CUnV',
#  '0wz1LjDb9ZNEYwOmDJ3Q4b',
#  '3yGy1JYz3zQKlxSgjgpQqX',
#  '0G21yYKMZoHa30cYVi1iA8',
#  '0KpMY3D2G8253VTZbDBUmA',
#  '7HKez549fwJQDzx3zLjHKC',
#  '6WrnSlcN0dzTO80mVVbBto',
#  '5SAUIWdZ04OxYfJFDchC7S',
#  '1q0wCfrE9eGFMzS2g8aVnx',
#  '0BhYMjZ5XFRdfZxsWCOwT0',
#  '1gcESexgftSuLuML57Y69q',
#  '6C7ZgThn6Yan5MTZdAEEFw',
#  '1I6q6nwNjNgik1Qe8Oi0Y7',
#  '52UcjsM15hjCQAUbTW2hy1',
#  '4dneV7C1yDt9UtyxrQY375',
#  '7o9uu2GDtVDr9nsR7ZRN73',
#  '33aYzW5ToRjiFOzkubeJ8H',
#  '4sscDOZCkbLSlDqcCgUJnX',
#  '29U7stRjqHU6rMiS8BfaI9',
#  '2VHfyWLlvCvbkIqtS5tqt3',
#  '0KrYPz4S4mKHeBjCwYJp0s',
#  '6MRxbDVnF00JvOhsKU1AXn',
#  '0hDQV9X1Da5JrwhK8gu86p',
#  '2RqX92TwDYaChAyfX9tKMH',
#  '3SUusuA9jH1v6PVwtYMbdv',
#  '0lnxrQAd9ZxbhBBe7d8FO8',
#  '3VwLD5o1r0YBLkjUfgSEYg',
#  '4IRHwIZHzlHT1FQpRa5RdE',
#  '6mSqWR95teJI6AXdMzDrjx',
#  '0fiSpF9mvRFQWy0ca64d1g',
#  '5EAilBkMwmAQH4obXtrNB3',
#  '5PLkbN1xEJ3KoF1tyqjpfZ',
#  '2zYzyRzz6pRmhPzyfMEC8s',
#  '2EqlS6tkEnglzr7tkKAAYD',
#  '0iOZM63lendWRTTeKhZBSC',
#  '7vvRkLPIvfjjmCIqNxBuEZ',
#  '4qGfJb2KByjvzrwo8HNibg',
#  '6fW4W5lfhRWNyoAiTGOevq',
#  '63wdqRslGFbxzMbvLo6UXj',
#  '28285KFbyCq8sJofn58qlD',
#  '0T702y9ndzZTnPq1bqiAM2',
#  '3rWlZxRCrBMcEL3QsSidr4',
#  '4cMHCRLPNoEbpnl2rz6GS9',
#  '4fpxnJGDWFxjGvLJOqPPt8',
#  '5G2g1EbEtFSMkMbAnhl7FV',
#  '5iGleL7HpEThuuYQ3us2jh',
#  '2XsW8N3mMRD5blv4KGNHq6',
#  '5IKLwqBQG6KU6MP2zP80Nu',
#  '5OGfBbWmRRkDiZiJbu5WIr',
#  '6Um3XCAxl9YfFmAnGl93xc',
#  '3gsCAGsWr6pUm1Vy7CPPob',
#  '0pQskrTITgmCMyr85tb9qq',
#  '0brrVj6VnvrG70SjRTnEJA',
#  '3mM14WXoPaLRjjkmxHe99L',
#  '48TNLcToLs8DWkdj5vYdiW',
#  '0fM0mFxHP1R4KPX1PB8tWU',
#  '5UgT7w6zVZjP3oyawMzbiK',
#  '6lFZbCc7pn6Lme1NP7qQqQ',
#  '2e4RcQohKWo8oZIUfjxiGo',
#  '4Q3vc39QZjLpGG7cS33kiC',
#  '1H7gMYGykdtwZOV6s1N0by',
#  '4AwKXevZmsTNa3KZVj3rzl',
#  '2fdfsGuqb6SBX5ocoBWHUd',
#  '6utiXjyN4dWoMNEZa2skxn',
#  '63BokRfXSQhEU6Qi2dSJpZ',
#  '3vF6NsyLWT9GRG30nrivk1',
#  '5JBGbFdBtLcCCygw8rtjli',
#  '557WVKv0CXtfKQJWRzBblP',
#  '2ccUQnjjNWT0rsNnsBpsCA',
#  '0yGEtWW1560pa3KHMzh0uc',
#  '5k8dJvnLKfv1YN9W3bO79x',
#  '5naGmbqRY9AlitnRgbw0uX',
#  '4jJfa4mO5JjV9Tz2aAxE2M',
#  '7j5Q3zhjvpQvMeoPSZwdsa',
#  '3c2kMiSB86tVq1J4oULmvL',
#  '0n2SEXB2qoRQg171q7XqeW',
#  '44pN9jfSqY3d3lrKuv3QeN',
#  '3Jw1RfDEUEBBIIyNjGt9xP',
#  '3UCmuRdeTriWgOZMEJsfqZ',
#  '66hdYurKbEfP74fvWtR7mj',
#  '2Bs1Lw9LX8hBm70t1iGdlh',
#  '5yMXAaSvxo12QkYU75Ixv0',
#  '3hJLKtTpgct9Y9wKww0BiR',
#  '18n0zch7bRo453Iwq98xYf',
#  '2dCmGcEOQrMQhMMS8Vj7Ca',
#  '6UBQONiLH8kNmmB8UrV2Ef',
#  '1JLn8RhQzHz3qDqsChcmBl',
#  '3ZpQiJ78LKINrW9SQTgbXd',
#  '6utJDOqzWj8FggDp1R2Wi2',
#  '4Wzt8Dm4xpO3LjWDecP4bA',
#  '3P4uUs9X0cPw7rf37NTndV',
#  '5D2lp16FQ0VIfLGRDn5jcG',
#  '1CapNlKgeOWlBEE54CRamd',
#  '4ZfQwNx3FlCN07cnUvekh3',
#  '5rb9QrpfcKFHM1EUbSIurX',
#  '47BBI51FKFwOMlIiX6m8ya',
#  '0onHzLoj8yQbjbHtJzwjBx',
#  '0HEmnAUT8PHznIAAmVXqFJ',
#  '4hdKgDxQMLEoiNwzL1Wu5y',
#  '1udKn1oNKYQSQ9OmiIWCMu',
#  '1wVtRjpBb8dnpZC8XSlmiy',
#  '1xShPgQbOUa98avWJQFDBY',
#  '4yQw7FR9lcvL6RHtegbJBh',
#  '62r1CS9zL1FL5Ilb7hLX7n',
#  '5TvcggVu3s2P1fMAS8BupX',
#  '2rslQV48gNv3r9pPrQFPW1',
#  '5vWMCGVeGxp3PEdvpDN3a0',
#  '3RCj5fG55qjtmnEML1gpnA',
#  '6Wnlq1Pu3I0BajLvxn05Vr',
#  '04KTF78FFg8sOHC1BADqbY',
#  '3Z2roouK8msGtMXAS7xWCJ',
#  '4ReyTz0y3TGkX48wO3Llot',
#  '2gam98EZKrF9XuOkU13ApN',
#  '3XG7bMVcMWLIn2k9jLAaAt',
#  '792UwI6utk5DMQUT1KXa5E',
#  '6mFkJmJqdDVQ1REhVfGgd1',
#  '17vPHgh4mReVZZNKEoTqmB',
#  '2wGSgTmgSF3xjRrHkTc25R',
#  '7HKxTNVlkHsfMLhigmhC0I',
#  '0MyY4WcN7DIfbSmp5yej5z',
#  '4jLv3tDBu8ww2R07DvL12s',
#  '39lSeqnyjZJejRuaREfyLL',
#  '53LZqMzQEnjBkFXPqOq0cD',
#  '2oDqmfa2g8W893LlwJG1qu',
#  '7foiOmd1Je7Z0D3TaZCDro',
#  '5tVA6TkbaAH9QMITTQRrNv',
#  '79nJj5dMyTsUzKvN5jUXsJ',
#  '1AAYbsAIgEJMbxgLgpjE9y',
#  '0KZodeWxqxd88F9wY1cqgs',
#  '0n2pjCIMKwHSXoYfEbYMfX',
#  '7KWoeBqSdZHEloYKVxssfG',
#  '0qvo5kciIqZJn1t8jdfqDn',
#  '7lQ8MOhq6IN2w8EYcFNSUk',
#  '1SY2vughwKmVPm1Lmf5Nl7',
#  '5JUhjSyjxtO4uEguZfyf26',
#  '39PU2z9LesM4HRvD6zY1Tg',
#  '0XnhQGfqfi5CnZXcONJuI5',
#  '5fdhThPDe6jQQDqCyWrdAn',
#  '6sBPjgvLZzHHrpxbBDjmdE',
#  '53AD8JznNIb0jUZvwFY6MB',
#  '5yR9u8QiOt8hJaddv32oo7',
#  '76TZCvJ8GitQ2FA1q5dKu0',
#  '2AF1drAUmMi8ZX0U97UJLw',
#  '1Bq65xKgu0kjSUMUlfWyPl',
#  '1xsY8IFXUrxeet1Fcmk4oC',
#  '7x2xjJV3YAPeLQJ7u3Kjet',
#  '3Cbh1EJ6OYAPkkNRuTIz6T',
#  '2qrOktpT4UcQKldz0QRCmD',
#  '4qgZs0RNjdzKAS22lP0QjY',
#  '7upgDi9C0pQn9HZzGfksJq',
#  '6NvRxjfYkkT2SpirAlmsjH',
#  '42mWEvGlwKGhVQs8XkvQKP',
#  '7nYvUtkQMx1v80S2FH2s9J',
#  '4vLYewWIvqHfKtJDk8c8tq',
#  '0gdmDP6xy3ZV7JNoHWAN9k',
#  '2M4PVaTJGjXV91X8HAVQEx',
#  '7EXgO1bRnEArE58rtrgMWB',
#  '1qV6e4ITnfGmA6m6Vklvbi',
#  '5K09WxKdlkroDyEVyOSySy',
#  '391TUcoPonqYykPkSZ5Z9U',
#  '6INLpBxo9F5QMer04VXEnd',
#  '0B1zVsLqmV9ibIFdNS5tGs',
#  '77K5TB5KZmDZCoJCdd1NvE',
#  '4aHFyOnxWuG532dD5viiDR',
#  '5CQvKyzkWI7TnUu2oB9QZ0',
#  '3IOQZRcEkplCXg6LofKqE9',
#  '3mwvKOyMmG77zZRunnxp9E',
#  '3GGcwG519BTMdvMeFy7meT',
#  '16KwF7IrKHTVTitUKH58g3',
#  '4W4wYHtsrgDiivRASVOINL',
#  '22AbXxQbMdVqEz7xJjhccG',
#  '08mG3Y1vljYA6bvDt4Wqkj',
#  '56rcBuVd1mpTeqP9cj3szc',
#  '0LzrhCZFXW94Y8nwtTuRlw',
#  '6bJuuCtXYiwOcKT9s8uRh8',
#  '0YEC3pNS0uIKvZb5u4lgsu',
#  '0uJyE3M3ecGZgzltsQKs3a',
#  '3qiyyUfYe7CRYLucrPmulD',
#  '79zQv3SsEOmyPAgUP4YDjz',
#  '77zlKibPvqudmNxMNpAtv6',
#  '5qBqBdfTEIWJwAS0Jm2F5R',
#  '3dp7r3Lm2IdS2ed5dyujbm',
#  '2DFRFqWNahKtFD112H2iEZ',
#  '2lwwrWVKdf3LR9lbbhnr6R',
#  '4lzTyLYXb3ED01TSLCJ1Hz',
#  '1wyVyr8OhYsC9l0WgPPbh8',
#  '37Dl7jQMmt0gUnzTKqnjkN',
#  '6KIKRz9eSTXdNsGUnomdtW',
#  '2Dsy7Ls7OuvG1fpjrKI5AE',
#  '2cwGK6ZYfiZ1EZva2VEKSN',
#  '6A8OnjnpShshNpcqWtZRjr',
#  '2NBQmPrOEEjA8VbeWOQGxO',
#  '6W5mQNW9bBqPdZq8RmJeVm',
#  '2DBlfjL5chsdeULzhTp5K8',
#  '2zMJN9JvDlvGP4jB03l1Bz',
#  '4FMNpPI7mkhdeFCCk6fZiE',
#  '52QqxUwMHSmeDZlZBABefY',
#  '1xKQbqQtQWrtQS47fUJBtl',
#  '653Fi3bqMxQQQmjw72ur6G',
#  '7wCmS9TTVUcIhRalDYFgPy',
#  '44iLnduItRWVrAy2zELmgx',
#  '4n1ZGm3TxYmoYe1YR8cMus',
#  '2qOm7ukLyHUXWyR4ZWLwxA',
#  '2nvcTDmZkRWKNMAL29sLHo',
#  '5uES1C2NgkdrNHiCwf9jRr',
#  '3eyT1c84NTXLLVkpUO0r9y',
#  '4P5KoWXOxwuobLmHXLMobV',
#  '2kgaPyVH4KY2s7PsYEgSIS',
#  '4jacsL77ZYnpInmTtUBaJW',
#  '760clbeDBWmBsBLbszWuNZ',
#  '5L8ta4ECl5zeA6bGqY7G38',
#  '7MegHaQmRiJT5mBooAs3JQ',
#  '3lwKNjchZuU5ZCVZVXwj5Y',
#  '5Q6GRDSFdRwE7H37dQop9u',
#  '34miSNKQ0xN7EG8zzzaFzI',
#  '0clmJYEzP2uw52oWcpireS',
#  '1YQWosTIljIvxAgHWTp7KP',
#  '3Dy4REq8O09IlgiwuHQ3sk',
#  '1XPta4VLT78HQnVFd1hlsK',
#  '1o6DclZHw0HomxXEQR1ijX',
#  '7kipZd4tWx6Mu8kBgB2Z2r',
#  '2h7w0KHwHbx4WbG6WxjO7U',
#  '3h4t9qpFktohHeUQc3hZCa',
#  '0lVdukU9ejbFQwZIhg47hx',
#  '5dNfHmqgr128gMY2tc5CeJ',
#  '2drXvACELcvwryaFRiRPdA',
#  '70wYA8oYHoMzhRRkARoMhU',
#  '3DlRZM6zKSlAZigHbJQ3cp',
#  '1VuBmEauSZywQVtqbxNqka',
#  '5LOKOBboMIbi4moxpjuFL5',
#  '4YMQXzscifAREG0a7KNGhB',
#  '0xyMlC1OYdO3JDl8406AEF',
#  '0dMd4rilfd6gPbXaLpNYhu',
#  '0QGwOFQChzflLAmPq5NwKo',
#  '39shmbIHICJ2Wxnk1fPSdz',
#  '0S8ibKBl3tjRmYbZhGHNhG',
#  '09WxJCWFMWAxTHBLLelpDS',
#  '1Ce0LuCifEoGTnf9MbXQbo',
#  '3R97rNX7JnmshCWBwOSFet',
#  '7uYyLVNjKY49L8o3AouXZd',
#  '758wEKVqfYopJIHYWdLVd4',
#  '79PrPZu9zWyc1qwUwXchVl',
#  '5NN5MQyE3Lo91zAEHpGa7S',
#  '5G9LvzXcBoIBXOd2jzdJTs',
#  '4t6NQkpUmvpvLDCkl3XuwA',
#  '7iG5yQkIIrd39mYWU2vT2b',
#  '2ItPID4dgSL1t1ZbZCrg5S',
#  '0MteK167vtyb6hoJNC3Uz3',
#  '4f8hBeMXMvssn6HtFAtblo',
#  '5BXn46DQ47dorQRMuJFeNJ',
#  '0d6m2xfXqMyEKOeRvfL7Ot',
#  '3dS7g2Cemp3bQEOqW9WbLm',
#  '59WN2psjkt1tyaxjspN8fp',
#  '6HSXNV0b4M4cLJ7ljgVVeh',
#  '11DjZQEZ69EXLo77HVj6yW',
#  '61K6lqGyrl2Aerk0LjAZem',
#  '2Mr1bGI2E10K7Mt1UJZ6Mw',
#  '0YZ3J8xzGwLOg4yEgST1YK',
#  '7FwBtcecmlpc1sLySPXeGE',
#  '683b4ikwa62JevCjwrmfg6',
#  '7oB0QBEnGRIJjvlDc8YnM6',
#  '4oh1goAlAK5FjkzjacrGPu',
#  '3aPlQWU07jGgyHaBHVS5TS',
#  '3vZO25GdYuqFrR1kzZADnp',
#  '11VwZwNF29HrqwalYUMitb',
#  '1QLr0zOu6fv5hLEHOwdr21',
#  '5TmQl8urbTlfZb8xKisSl0',
#  '1PehfITh0TTRx3LkDdV4h3',
#  '0VE4ayVlGs5DBoqOdgJ0Zv',
#  '5Z6LSi0xvgW8LU09SwAeGZ',
#  '7uqrG7OormbZVoLhFY9bLx',
#  '7ITRNB9OckYIp2SW2iXU8U',
#  '2qhASBzpbFhPRtrnZ5lLnz',
#  '1oYYd2gnWZYrt89EBXdFiO',
#  '3rzYUfyzdZW96cHXnGn1xI',
#  '7B2pUwzvlbNG9D855r9ugf',
#  '5hReWjUHqPqkHi31G7izL4',
#  '0rcLhYRihks3t4lFPtHhQV',
#  '6KTv0Z8BmVqM7DPxbGzpVC',
#  '1pKYYY0dkg23sQQXi0Q5zN',
#  '6HxweNytuEQdmGeVtZPZz3',
#  '6OsefWNJtsWqO7myze1HEX',
#  '39QBkWKnap8wRSW4WB9OK0',
#  '1tZKsxgKebVQX9s6oiojG9',
#  '6pmuu4qSz2WrtGkBjUfyuz',
#  '4SGBuq37Ol4HJr7pQqFMKa',
#  '2R3g9k14OAcUzZYwo90Tx6',
#  '7Lf7oSEVdzZqTA0kEDSlS5',
#  '4d6eqRtpDX7tydHJGDZUBQ',
#  '5LyfiK6iXEIBNEtcaGKohl',
#  '55q3Ro66yXWi9rsEddeEN4',
#  '5geF5xzPGHxpmk9BDBHphZ',
#  '29SRvYOKbMLOZeOubNGtLb',
#  '08FHOG2zOkqCQ0IYOmJ5bj',
#  '0odIT9B9BvOCnXfS0e4lB5',
#  '4a01ClusxuZiloOK5UgLUn',
#  '7vAw4LLIms6X8ZHcbtoazz',
#  '4alHo6RGd0D3OUbTPExTHN',
#  '0Bs0hUYxz7REyIHH7tRhL2',
#  '6A28sLdLOf9vohN5LVl5KR',
#  '003vvx7Niy0yvhvHt4a68B',
#  '63OQupATfueTdZMWTxW03A',
#  '0cOf4csnt4DeXSkFmBjULw',
#  '0Z3Y5cWOPaXIBI08KKDVTO',
#  '6MrILERJLA3Jcq0E9poZsp',
#  '31CUzsUuvz1EhTbT6MfqDU',
#  '1HOMkjp0nHMaTnfAkslCQj',
#  '3Ap7YIpMkjNiyZnRJiWsVy',
#  '4INDiWSKvqSKDEu7mh8HFz',
#  '6Szw3sQC5Zssr15AJsUY9J',
#  '4wYq5wugZDzQiMZQYG4wVB',
#  '6hNOgftznEOoTrermrc30D',
#  '3rsU41myYJwlHNASyuP5es',
#  '3vyKSb9sAdXl0kQ1KnS9fY',
#  '5dUMh0ugelpKfoFp3qChuK',
#  '7CqleiaEqHVazV19P532X9',
#  '18LwhRYqFsJjUH3Q4dMIr7',
#  '2SHTKB8YYlawTGIuJ2b2ok',
#  '6qAzb3rsqoC3YDFbWWExHF',
#  '2KkJj006V93x8d9dXpgmIg',
#  '1n00Xu0vbe6jUaR3df4hqX',
#  '73mlvsfJM2qwlDUJxeaatI',
#  '6LXh42hEpcVLKtUgVkiKZi',
#  '6S55C80YzjhSrCRRd1p80b',
#  '1UDDeiefJTAYMMWFab9Rsh',
#  '0DiWol3AO6WpXZgp0goxAV',
#  '7KwZNVEaqikRSBSpyhXK2j',
#  '0VmTayc6Xw6YujsNXLWWJ2',
#  '5FzBxhIsZBFXDTVGWtV4IQ',
#  '3lAun9V0YdTlCSIEXPvfsY',
#  '4GWHrdyVTC0AWwuRgoWzE7',
#  '1L94M3KIu7QluZe63g64rv',
#  '7k42ztYdHyKWrKrENxwjkV',
#  '4TOMI010Sd4ZAX4aZ5TS85',
#  '5ibELGcXGqX5x9TWFeNPxY',
#  '15kLz0zNFdtsaJdXKSGmTU',
#  '3Uh7rAb7F0XGVpEEDwfH1k',
#  '3fNf71Ktya4CYMqGM6eRud',
#  '6egDwGxJ7usnZvssKWknyz',
#  '6DDhXGwCHmzT3EVoXr9lS2',
#  '3lh3iiiJeiBXHSZw6u0kh6',
#  '5gJKsGij5oGt5H5RSFYXPa',
#  '2nWHzbBWBOePUvAImQv2So',
#  '7cNRqg0lbiqBaGeOlA4AEU',
#  '6vcG9EgeqJUSmmF65lxUm6',
#  '6u91CCTziobh3twCDMBlEk',
#  '4AUS8KNz7zX8XFu9L38GT0',
#  '7s8spWIA65WP6vG18bXDP1',
#  '0emd9tHSVP4dK6UG4pcOFD',
#  '1mfV2kv9RwFKVI8kEQlmOJ',
#  '7F3WTjeqzK6wurRKoWgeNc',
#  '74ohdXevc7VsXl96ofi3Kn',
#  '2JOJBxwRHWYcdXiOxZmoFv',
#  '1waLmkUyMq0M5ACmf5SG7q',
#  '62fX8EW16l8St2yL8rMer9',
#  '3yfqSUWxFvZELEM4PmlwIR',
#  '66Yxbr2UODJjVBKdZtbnOL',
#  '6PypGyiu0Y2lCDBN1XZEnP',
#  '3IDc87lrpEHWFBASmgTgFV',
#  '3EnyKqEJFylT6vU1KF0YyE',
#  '4cgodXjv4TfrooNQxvlO4O',
#  '1Ex3FSidOBkODU3pcsCRYK',
#  '1YhyOTcVjHe73cm6tYrHkA',
#  '4LcrHUkRmXG3c0YD5VYutn',
#  '7uMiAVsZy9Iash5gPsoTxe',
#  '3CH8M5lB931faZDzjCTfVW',
#  '3IeCYkdKI55mNMl2o4vX0k',
#  '3LRJbFT9rKoKv4aW7PuBJC',
#  '1v1PV2wERHiMPesMWX0qmO',
#  '1tH8ycIrUoZt94f82MrVL5',
#  '1MV5BzujqyRQ417qj0rXNS',
#  '3RkQ3UwOyPqpIiIvGVewuU',
#  '0jTyjoIkknooAyNpwbFuCT',
#  '7jVBSPLSbL1jKVBDMXlRCx',
#  '2xGDWFTlEYIaPkS9ahOXBz',
#  '2YxXuCdbUpil3P7tRjhW1t',
#  '5jaVyz2GDdesyu01cBbOSc',
#  '4D40ZlFAWsvX7lua1Kablh',
#  '7ywlnXV5O0h8T5pCRUN1f5',
#  '5IVaPiiBCUgsNp3kWeU5c2',
#  '5eNMSdh1hY72WrpaBZjA4B',
#  '22sLuJYcvZOSoLLRYev1s5',
#  '49MHCPzvMLXhRjDantBMVH',
#  '5ckwOX7SVzt9OISbGkD299',
#  '30lxTiMzVRxp6wLcTn6awC',
#  '6h3YJ05BovN1Pgk145J3r9',
#  '0vV3IUO4fhuDeHggZqnsI0',
#  '60fKMm3ts4mBzvfCityzUg',
#  '0hlvq1AsRKPYgAnshziWzZ',
#  '07OzC5JlcaDwEkzWmvqp6y',
#  '6F2vo4sxRNQ58VYe3pdiaL',
#  '2xm9ihELo6xwrRKrBbPql9',
#  '11IzgLRXV7Cgek3tEgGgjw',
#  '7qTZ3NYt0p2Bdyaq4YS6UL',
#  '37CRPk0L5ZpfPeePEPwE0t',
#  '2LvD3a2C0Jt0r0jW5bwOuU',
#  '1zU0kAJdEPyRs4x5gkQQER',
#  '2DiKZXh31aHrOUTfNjVXpJ',
#  '7ziicmUOzWXAkdPriOmFk9',
#  '3sqZDdEO5viqNqMCNem5m5',
#  '3geRffSf6eAruhg23RkpKV',
#  '2RvoIv22fdI9Uhife5zdDl',
#  '08gcSzRD66Dc7z3x6yigol',
#  '5izGeTxueiFX1UPFGohY9w',
#  '0Nn4RrvVfwSSLDvkhdRc1n',
#  '1l2Xmg54EUr3TDzNIaCr1z',
#  '2GKYEk8NQkafOqSw4uWZXl',
#  '4d6FHaOlHLo4sGpMXaexho',
#  '0Q0IVlqMV64kNLlwjPj0Hl',
#  '0deAIqyKFFw55JDMGWTcdA',
#  '0gljI0CtjpdZK6ecidfxto',
#  '7oOOI85fVQvVnK5ynNMdW7',
#  '250dZY8xYbhHGQpM6bgL52',
#  '3hx5R8nOKu5zvhlfDNSIQC',
#  '0KQx6HOpJueiSkztcS0r7D',
#  '35ySEC3RyS1w36bkpgj1lT',
#  '0OM9ri37LIbPc9hffwsyb1',
#  '0jerRsvPriEWOEz8SjWupO',
#  '5U1UqrvzDDj22eyFocTtmr',
#  '3D9iV6cYkYJRAPFO6DRKIE',
#  '5qYp7YDkLAaSd1nBWejkAD',
#  '4XRcPVLVKhdAy7STWO1LnI',
#  '7w5AOd6HrDIHewHfpABEss',
#  '2swv9viYTRGz9RQ9ko4jWL',
#  '6IIcvtmuGpWIasqOpyGlyY',
#  '66BjgQodHebiX5QGpBAjyQ',
#  '4wcWI3GEtaGm38dbdDFbyI',
#  '1ng36571Iyov4HBxUClySn',
#  '2VNfJpwdEQBLyXajaa6LWT',
#  '07GtDOCxmye5KDWsTSACPk',
#  '5g1vtHqi9uV7xtYeCcFOBx',
#  '1CtAzw53AIXKjAemxy4b1j',
#  '7jeOETwLUP84mPQzxlD5nh',
#  '4eHbdreAnSOrDDsFfc4Fpm',
#  '5h8ve1B7Gr3k4W0WXAgLxE',
#  '5OcyX5eg7VrJuI833qOCUc',
#  '54flyrjcdnQdco7300avMJ',
#  '3YdP82XA3ARj8uY1vwmxEk',
#  '55f4JiHsK46ftCjzr5CiKl',
#  '2V4Bc2I962j7acQj1N0PiQ',
#  '2xMAFTxwZ0w1twuyMZcYb7',
#  '1ibRqifchaAfeNdQGpbRVW',
#  '4l9hml2UCnxoNI3yCdL1BW',
#  '2eOFGf5MOA5QHGLY9ZlOfl',
#  '6Ht0wBgRgLQPjIQKks766b',
#  '5Vdg4tP25ffeGEC5GGmCwm',
#  '0zP0XEo0WOJZ31WUihCabf',
#  '0y5CnV2idm2KkQEudDjfDT',
#  '1D1PV0JIxcyxlGNFey8gGm',
#  '2EC9IJj7g0mN1Q5VrZkiYY',
#  '1VN8ew9KECPqYS3sVbnZRr',
#  '7bqaKsfrVZtHOoaV78i7N9',
#  '5VdYenFr9hnB0jTBDzs9NC',
#  '70C4NyhjD5OZUMzvWZ3njJ',
#  '64D3dzWyj0GpQT1AHx4kbK',
#  '6NBGabiAuQklrfkufcOqlN',
#  '4h5KBcltGefua73AUPYps7',
#  '4ueq6n73MAh23KMabKrpI0',
#  '3oyc1mIdCBGaU55wX7otqM',
#  '7tJQ4Ekp2vN3NlI3vJJW3v',
#  '2laui4O0tY1GDZcsB7iJtK',
#  '1lnQ6kkVaHg0Itdx88REdJ',
#  '67Hna13dNDkZvBpTXRIaOJ',
#  '6tEJxuPnNDv6XL49nZEW7f',
#  '6SN51pk4UOfKa9Q9DoXEtF',
#  '3M8FzayQWtkvOhqMn2V4T2',
#  '2L93TdW2GMue1H2zlkt30F',
#  '09hxCc0SgV8u46gWsfeqJA',
#  '2XYNq7LIQrh82m7LPiPN8w',
#  '6t1FIJlZWTQfIZhsGjaulM',
#  '6WE7jSshLCuVKoCmobVKVf',
#  '3GXo1eWlT2flv4x01l5OTu',
#  '1so0qYkfkiZNNcvJN02qdo',
#  '1p80AptLonBW0VilSi6xFj',
#  '3qLZ866ZfaK0B0R5FIqXLG',
#  '6bkL6phWAdD9ll9SG47108',
#  '7mAF2MJdbNT75VrVcgwT6F',
#  '4VARbg9JGQXxc3HBEv1Oy4',
#  '4qpIk2rvkmxJEVvt38tepd',
#  '2x5FYXo5rL4Phmn3UPdkK3',
#  '5TppzvNWFQmpSztrhRpM0j',
#  '0pzjcWYkyynxhONSm5C8Cu',
#  '11607FzqoipskTsXrwEHnJ',
#  '0xuXRQJfxmdP6gvfDe2Z4L',
#  '4D2JmiX0P8WJygnpV80WTs',
#  '4aR9bPMAOFySBuQSbVWF3d',
#  '6SR0dDuXH2vtgBfMLrivKV',
#  '4XRkQloZFcRrCONN7ZQ49Y',
#  '3mlMpmY8oZIBFc39D9zLbh',
#  '7iFdUmdqT9XrsJdSGf9KrX',
#  '3hNUYt4dMM9RhcWmty8oKF',
#  '3uCkIqD0VzQUijbs8WIizs',
#  '62Yu8QL1g9pdbvN4XL9Rah',
#  '0iPJYeAwkyUrdNOwHM1E7t',
#  '6EHuOufBeL6vk3TvVJB5qo',
#  '7D1TXsAL2fCgVtWaDw4Uag',
#  '0r9NLcp6718EYibVX6diWN',
#  '1ZozGivTAYsOwhy6LVHsPX',
#  '18AXbzPzBS8Y3AkgSxzJPb',
#  '51KKQAgYFoJHgVIuJWHdHb',
#  '5Lhjlnly9Ynhf52ojQS534',
#  '0QvgVegt9G5zg2RWQ5EM29',
#  '6YYd5MLpu45J0uLrMdivF7',
#  '5PoJexKnOMRlGSBLscR7RK',
#  '4WNEDjXbuCWnceZPOEkf0S',
#  '1WPqawIF9HCKfSOt7mN6X0',
#  '4zJBF8rXepeoJ0qJOqMLhj',
#  '2VVROOX0ibcw7PThGkAhiz',
#  '3ckd4YA4LcD3j50rfIVwUe',
#  '1GcVa4jFySlun4jLSuMhiq',
#  '7KaSmr2Ha3p96JHwpHGSKu',
#  '6kotXaSQaGYxE62hVpdHWu',
#  '1xxPQaR29dAf3yxaafByeD',
#  '1yupbrI7ROhigIHpQBevPh',
#  '6l4wMAXzI8RxIysQMYZY0w',
#  '1oTHteQbmJw15rPxPVXUTv',
#  '1XT5kxg6Tk0ukCO2vBQN4v',
#  '6wVViUl2xSRoDK2T7dMZbR',
#  '2vULfNEAOjjRyjj6hs0kBm',
#  '7qoaMWT3eRCKG1RN6dVuOY',
#  '1L9fzw2pXprOqtemTwtxXF',
#  '2TVxnKdb3tqe1nhQWwwZCO',
#  '6cIeXq9VgP8y0638xOiQpw',
#  '0GONea6G2XdnHWjNZd6zt3',
#  '4kYyTWYSTDpezW8ysC241Q',
#  ...]

# %%
audio_features_nothotdf = get_audio_features(filtered_ids_nothot)
# Out:
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...
# Sleep...

# %%
not_hot_features = add_audio_features(not_hot, audio_features_nothotdf, 'id')

# %%
not_hot_features.head()
# Out:
#                artist                          title                      id  \
# 0           Bob Dylan           Like a Rolling Stone  3AhXZa8sUQht0UEdBJgpGc
# 1  The Rolling Stones  (I Can't Get No) Satisfaction  2PzU4IB8Dr6mxV3lHuaG34
# 2      The Beach Boys                Good Vibrations  5t9KYe0Fhd5cW6UYT4qP8f
# 3             Nirvana        Smells Like Teen Spirit  5ghIJDpPoe3CfHMGu71E6T
# 4     Aretha Franklin                        Respect  7s25THrKz86DM225dOYwnr
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.482   0.721    0    -6.839     1       0.0321      0.731000
# 1         0.723   0.863    2    -7.890     1       0.0338      0.038300
# 2         0.396   0.473   10    -7.670     0       0.0345      0.326000
# 3         0.502   0.912    1    -4.556     1       0.0564      0.000025
# 4         0.805   0.558    0    -5.226     1       0.0410      0.164000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1890    0.557   95.263  audio_features
# 1          0.031700    0.1280    0.931  136.302  audio_features
# 2          0.000124    0.1090    0.385  133.449  audio_features
# 3          0.000173    0.1060    0.720  116.761  audio_features
# 4          0.000022    0.0546    0.965  114.950  audio_features
#
#                                     uri  \
# 0  spotify:track:3AhXZa8sUQht0UEdBJgpGc
# 1  spotify:track:2PzU4IB8Dr6mxV3lHuaG34
# 2  spotify:track:5t9KYe0Fhd5cW6UYT4qP8f
# 3  spotify:track:5ghIJDpPoe3CfHMGu71E6T
# 4  spotify:track:7s25THrKz86DM225dOYwnr
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3AhXZa8sUQht...
# 1  https://api.spotify.com/v1/tracks/2PzU4IB8Dr6m...
# 2  https://api.spotify.com/v1/tracks/5t9KYe0Fhd5c...
# 3  https://api.spotify.com/v1/tracks/5ghIJDpPoe3C...
# 4  https://api.spotify.com/v1/tracks/7s25THrKz86D...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3AhX...       369600
# 1  https://api.spotify.com/v1/audio-analysis/2PzU...       222813
# 2  https://api.spotify.com/v1/audio-analysis/5t9K...       219027
# 3  https://api.spotify.com/v1/audio-analysis/5ghI...       301920
# 4  https://api.spotify.com/v1/audio-analysis/7s25...       147600
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
not_hot_features.shape
# Out:
# (2767, 20)

# %%
not_hot_features.to_csv('not_hot_features.csv')

# %%
# %%writefile functions_api.py

import pandas as pd
from time import sleep
import numpy as np
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import sys
from config import *

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))

def search_song(title, artist, limit = 1):
    '''
    Function to search a given single song in the Spotify API. 
    Input: title = song name, artist = song singer
    Output: song id from Spotify
    '''
    
    search_query = f"track:{title} artist:{artist}"
    id = sp.search(q = search_query, limit = limit)['tracks']['items'][0]['id']
    return id 

def add_id(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Function to obtain the IDs of a given list of songs through the Spotify API.
    Input: pd.DataFrame
    Output: pd.DataFrae with the column "id" for each song
    Chunks used in order to prevent reaching the API request limit 
    '''
    
    chunks = 50
    list_of_ids = []

    for i in range(0, len(df), chunks):
        chunk = df.iloc[i:i+chunks]
        print("Collecting IDs for chunk...")
    
        for index, row in chunk.iterrows():
            title = row["title"]
            artist = row["artist"]
            try:
                id = search_song(title, artist, 1)
                list_of_ids.append(id)
            except:
                print("Song not found!")
                list_of_ids.append("")
        sleep(20)
        print("Sleep...")

    df["id"] = list_of_ids
    return df

def get_audio_features(list_of_ids: list) -> pd.DataFrame:
    '''
    Function to obtain the audio features of a given list of songs 
    Input: List with the song ids 
    Output: pd.DataFrame with the audio features for each id
    Chunks used in order to prevent reaching the API request limit
    '''
    
    chunks = 50
    audio_features = []

    for i in range(0, len(list_of_ids), chunks):
        chunk_ids = list_of_ids[i:i+chunks]
        try:
            features_chunk = sp.audio_features(tracks = chunk_ids)
            if features_chunk:
                audio_features.extend(features_chunk)  
        except:
                print("Error retrieving audio features for chunk!")
                
        sleep(20)
        print("Sleep...")
        
    audio_features = [af for af in audio_features if af is not None]
    audio_features_df = pd.DataFrame(audio_features)

    return audio_features_df

def add_audio_features(df: pd.DataFrame, audio_features_df: pd.DataFrame, key_column) -> pd.DataFrame:
    '''
    Function to merge the original df with the created df which has the song features.
    Input: df: pd.DataFrame -> original df, audio_features_df and the column on which both will merge 
    Output: The merged dataframe from the input ones
    '''

    merged_df = pd.merge(df, audio_features_df, how = 'inner', on = key_column)
    return merged_df
# Out:
# Writing functions_api.py
